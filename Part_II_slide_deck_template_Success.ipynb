# %% [markdown]
# # Part II - Prosper Loan Data Analysis
# ## by Success Osakioduwamen Obazee

# %% [markdown]
# ## Investigation Overview
#
#
# > In this investigation, I will be looking at the Employment Status of the borrowers.
#
# ## Dataset Overview
#
# > The dataset contains 55071 loans with 13 features (including LoanOriginalAmount, BorrowerAPR, StatedMonthlyIncome, EmploymentStatus and many others)

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sb
sb.set_style('darkgrid')
matplotlib.style.use('ggplot')


# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe

loan_df = pd.read_csv('Loan_cleaned.csv')

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55071 entries, 0 to 55070
# Data columns (total 13 columns):
# Unnamed: 0             55071 non-null int64
# LoanOriginalAmount     55071 non-null int64
# LoanStatus             55071 non-null object
# ListingCategory        55071 non-null object
# BorrowerState          49559 non-null object
# BorrowerAPR            55046 non-null float64
# BorrowerRate           55071 non-null float64
# StatedMonthlyIncome    55071 non-null float64
# Term                   55071 non-null int64
# EmploymentStatus       52819 non-null object
# MonthlyLoanPayment     55071 non-null float64
# date                   55071 non-null object
# time                   55071 non-null object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 5.5+ MB

# %% [markdown]
# ## Employment Status
#
# > The majority of borrowers are currently employed and work full-time..

# %%
loan_df['EmploymentStatus'].value_counts().plot(kind='bar')
plt.title('Employment Status')
plt.xlabel('count')
plt.ylabel('EmploymentStatus')
plt.fontsize = 12
plt.figsize=(10,10)

# %% [markdown]
# ## Term
#
# >* There are only 3 loan terms, and the majority of loan term is for the 36 months

# %%
sb.countplot(data = loan_df, x = 'Term');
plt.title('Term');

# %% [markdown]
# ## Loan Status and Loan Amount
#
# > Defaulted and chargedoff credits tend to be smaller than completed credits ones.

# %%
sb.boxplot(data = loan_df, x = 'LoanStatus', y = 'LoanOriginalAmount');
plt.title('Loan Status Vs Loan Amount');

# %% [markdown]
# ## Employment Status Vs Term
#
# > The Full time employed borrowers have a longer term loan of 36 months

# %%
plt.figure(figsize = [15, 10])
sb.countplot(data = loan_df, x = 'EmploymentStatus', hue = 'Term', palette = 'Reds');
plt.title('Employment Status Vs Term');

# %% [markdown]
# ## Employment Status Vs Loan Original Amount
#
# > The full time employed borrowers have a higher amount of loan than the others

# %%
np.linspace(0, 35000, 55)
g=sb.FacetGrid(data=loan_df, col='EmploymentStatus', size=4)
g.map(plt.hist, 'LoanOriginalAmount')
plt.title('Employment Status Vs Loan Original Amount');

# %% [markdown]
# ## Employment Status Vs Stated Monthly Income
#
# > The Self-Employed borrowers have the highest monthly income

# %%
plt.figure(figsize = [10,5])
sb.boxplot(data = loan_df, x = 'EmploymentStatus', y = 'StatedMonthlyIncome');
plt.title('Employment Status Vs Stated Monthly Income');

# %% [markdown]
# ## Employment Status, Loan Original Amount and Loan Status
#
# > Employed workers has the highest Completed Loan in the loan amount

# %%
plt.figure(figsize = [12, 8])
sb.boxplot(data=loan_df, x='EmploymentStatus', y='LoanOriginalAmount', hue='LoanStatus');
plt.title('EmploymentStatus and LoanOriginalAmount vs LoanStatus');

# %% [markdown]
# ## Employment Status, BorrowerAPR and Term
#
# > Retired employees has the lowest borrower APR on a 12 month loan term

# %%
fig = plt.figure(figsize = [10,7])
ax = sb.barplot(data = loan_df, x = 'EmploymentStatus', y = 'BorrowerAPR',  hue = 'Term', palette = 'Set1_r')
plt.title('Borrower APR Based on Employment Status and Term')
plt.xlabel('EmploymentStatus')
plt.ylabel('Borrower APR')
plt.xticks(rotation = 60)
ax.legend(loc='center left', title='Term', bbox_to_anchor=(1, 0.5))
plt.show();

# %%
# !jupyter nbconvert Part_II_slide_deck_template_Success.ipynb --to slides --post serve  --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template_Success.ipynb to slides
# [NbConvertApp] Writing 283806 bytes to Part_II_slide_deck_template_Success.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck_template_Success.slides.html
# Use Control-C to stop this server
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: x-www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: firefox: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: iceweasel: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: seamonkey: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: mozilla: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: epiphany: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: konqueror: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: chromium-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: google-chrome: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 778: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'http://127.0.0.1:8000/Part_II_slide_deck_template_Success.slides.html'
